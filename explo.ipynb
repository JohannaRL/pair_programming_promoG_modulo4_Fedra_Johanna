# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##### Exploración CSV movie_info

# %%
df_info = pd.read_csv("./files/movie_info.csv")
df_info
# Out:
#                                   movie_title       release_date  season  \
# 0                                    Iron Man        May 2, 2008  Spring
# 1                         The Incredible Hulk      June 13, 2008  Spring
# 2                                  Iron Man 2        May 7, 2010  Spring
# 3                                        Thor        May 6, 2011  Spring
# 4          Captain America: The First Avenger      July 22, 2011  Summer
# 5                                The Avengers        May 4, 2012  Spring
# 6                                  Iron Man 3        May 3, 2013  Spring
# 7                        Thor: The Dark World   November 8, 2013    Fall
# 8         Captain America: The Winter Soldier      April 4, 2014  Spring
# 9                     Guardians of the Galaxy     August 1, 2014  Summer
# 10                    Avengers: Age of Ultron        May 1, 2015  Spring
# 11                                    Ant-Man      July 17, 2015  Summer
# 12                 Captain America: Civil War        May 6, 2016  Spring
# 13                             Doctor Strange   November 4, 2016    Fall
# 14             Guardians of the Galaxy Vol. 2        May 5, 2017  Spring
# 15                     Spider-Man: Homecoming       July 7, 2017  Summer
# 16                             Thor: Ragnarok   November 3, 2017    Fall
# 17                              Black Panther  February 16, 2018  Winter
# 18                     Avengers: Infinity War     April 27, 2018  Spring
# 19                       Ant-Man and the Wasp       July 6, 2018  Summer
# 20                             Captain Marvel      March 8, 2019  Winter
# 21                          Avengers: Endgame     April 26, 2019  Spring
# 22                  Spider-Man: Far From Home       July 2, 2019  Summer
# 23                                Black Widow       July 9, 2021  Summer
# 24  Shang-Chi and the Legend of the Ten Rings  September 3, 2021  Summer
# 25                                   Eternals   November 5, 2021    Fall
# 26                    Spider-Man: No Way Home  December 17, 2021    Fall
#
#     phase  production_budget_in_million_(USD)  \
# 0       1                                 140
# 1       1                                 150
# 2       1                                 200
# 3       1                                 150
# 4       1                                 140
# 5       1                                 220
# 6       2                                 200
# 7       2                                 170
# 8       2                                 170
# 9       2                                 170
# 10      2                                 250
# 11      2                                 130
# 12      3                                 250
# 13      3                                 165
# 14      3                                 200
# 15      3                                 175
# 16      3                                 180
# 17      3                                 200
# 18      3                                 325
# 19      3                                 162
# 20      3                                 160
# 21      3                                 356
# 22      3                                 160
# 23      4                                 200
# 24      4                                 150
# 25      4                                 200
# 26      4                                 200
#
#     worldwide_collection_in_million_(USD)  tomatometer  tomato_audience_score  \
# 0                                  585.37          9.4                    9.1
# 1                                  264.77          6.7                    7.0
# 2                                  623.93          7.2                    7.1
# 3                                  449.33          7.7                    7.6
# 4                                  370.57          7.9                    7.5
# 5                                 1518.82          9.1                    9.1
# 6                                 1214.81          7.9                    7.8
# 7                                  644.78          6.6                    7.5
# 8                                  714.42          9.0                    9.2
# 9                                  773.35          9.2                    9.2
# 10                                1402.81          7.6                    8.3
# 11                                 519.31          8.3                    8.5
# 12                                1153.34          9.0                    8.9
# 13                                 677.80          8.9                    8.5
# 14                                 863.76          8.5                    8.7
# 15                                 880.17          9.2                    8.7
# 16                                 853.98          9.3                    8.7
# 17                                1347.60          9.6                    7.9
# 18                                2048.36          8.5                    9.1
# 19                                 622.67          8.7                    8.1
# 20                                1128.46          7.9                    4.5
# 21                                2797.50          9.4                    9.0
# 22                                1131.93          9.0                    9.5
# 23                                 379.75          7.9                    9.1
# 24                                 432.24          9.1                    9.8
# 25                                 402.06          4.7                    7.8
# 26                                1892.62          9.3                    9.8
#
#     imdb  metascore  meta_user_score
# 0    7.9        7.9              8.6
# 1    6.6        6.1              7.0
# 2    6.9        5.7              6.4
# 3    7.0        5.7              7.1
# 4    6.9        6.6              6.8
# 5    8.0        6.9              8.0
# 6    7.1        6.2              6.7
# 7    6.8        5.4              7.1
# 8    7.8        7.0              8.3
# 9    8.0        7.6              8.2
# 10   7.3        6.6              7.1
# 11   7.3        6.4              7.5
# 12   7.8        7.5              8.0
# 13   7.5        7.2              8.0
# 14   7.6        6.7              7.8
# 15   7.4        7.3              7.6
# 16   7.9        7.4              7.8
# 17   7.3        8.8              6.3
# 18   8.4        6.8              8.6
# 19   7.0        7.0              7.1
# 20   6.8        6.4              3.0
# 21   8.4        7.8              7.9
# 22   7.4        6.9              7.6
# 23   6.7        6.7              6.1
# 24   7.4        7.1              7.1
# 25   6.4        5.2              6.3
# 26   8.4        7.1              8.6

# %%
def exploracion_dataframe(dataframe):

    #Nos enseña los duplicados en el DF

    print(f"Tenemos {dataframe.duplicated().sum()} duplicados en el conjunto de datos.")
    print("\n ----- \n")

    #Nos muestra un DataFrame para los valores nulos

    print("Los nulos que tenemos en el conjunto de datos son:")
    df_nulos = pd.DataFrame(dataframe.isnull().sum() / dataframe.shape[0] * 100, columns = ["%_nulos"])
    display(df_nulos[df_nulos["%_nulos"] > 0])
    print("\n ----- \n")

    #Nos muestra los tipos de columnas

    print(f"Los tipos de las columnas son:")
    display(pd.DataFrame(dataframe.dtypes, columns = ["tipo_dato"]))
    print("\n ----- \n")

    #Nos muestra los valores de las columnas categóricas

    print("Los valores que tenemos para las COLUMNAS CATEGÓRICAS son: ")
    dataframe_categoricas = dataframe.select_dtypes(include = "O")
    for col in dataframe_categoricas.columns:
        print(f"La columna {col.upper()} tiene las siguientes valores únicos:")
        display(pd.DataFrame(dataframe[col].value_counts()).head())

    #Sacamos los principales estadísticos de cada una de las categorías
    
    columnas_numericas = dataframe.select_dtypes(include=['int', 'float']).columns
    columnas_categoricas = dataframe.select_dtypes(include='O').columns
    for col in columnas_categoricas:
        print("\n ----- \n")
        print(f"Los principales estadísticos de las COLUMNAS CATEGÓRICAS para el {col.upper()} son: ")
        display(dataframe[[col]].describe().T)
    for col in columnas_numericas:
        print("\n ----- \n")
        print(f"Los principales estadísticos de las COLUMNAS NUMÉRICAS para el {col.upper()} son: ")
        display(dataframe[[col]].describe().T)

# %%
exploracion_dataframe(df_info)
# Out:
# Tenemos 0 duplicados en el conjunto de datos.
#
#  -----
#
# Los nulos que tenemos en el conjunto de datos son:
# Empty DataFrame
# Columns: [%_nulos]
# Index: []
#  -----
#
# Los tipos de las columnas son:
#                                       tipo_dato
# movie_title                              object
# release_date                             object
# season                                   object
# phase                                     int64
# production_budget_in_million_(USD)        int64
# worldwide_collection_in_million_(USD)   float64
# tomatometer                             float64
# tomato_audience_score                   float64
# imdb                                    float64
# metascore                               float64
# meta_user_score                         float64
#  -----
#
# Los valores que tenemos para las COLUMNAS CATEGÓRICAS son:
# La columna MOVIE_TITLE tiene las siguientes valores únicos:
#                                            count
# movie_title
# Iron Man                                       1
# Guardians of the Galaxy Vol. 2                 1
# Eternals                                       1
# Shang-Chi and the Legend of the Ten Rings      1
# Black Widow                                    1
# La columna RELEASE_DATE tiene las siguientes valores únicos:
#                    count
# release_date
# May 2, 2008            1
# May 5, 2017            1
# November 5, 2021       1
# September 3, 2021      1
# July 9, 2021           1
# La columna SEASON tiene las siguientes valores únicos:
#         count
# season
# Spring     12
# Summer      8
# Fall        5
# Winter      2
#  -----
#
# Los principales estadísticos de las COLUMNAS CATEGÓRICAS para el MOVIE_TITLE son:
#             count unique       top freq
# movie_title    27     27  Iron Man    1
#  -----
#
# Los principales estadísticos de las COLUMNAS CATEGÓRICAS para el RELEASE_DATE son:
#              count unique          top freq
# release_date    27     27  May 2, 2008    1
#  -----
#
# Los principales estadísticos de las COLUMNAS CATEGÓRICAS para el SEASON son:
#        count unique     top freq
# season    27      4  Spring   12
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el PHASE son:
#        count      mean       std  min  25%  50%  75%  max
# phase   27.0  2.481481  1.014145  1.0  2.0  3.0  3.0  4.0
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el PRODUCTION_BUDGET_IN_MILLION_(USD) son:
#                                     count        mean        std    min  \
# production_budget_in_million_(USD)   27.0  191.592593  52.859217  130.0
#
#                                       25%    50%    75%    max
# production_budget_in_million_(USD)  160.0  175.0  200.0  356.0
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el WORLDWIDE_COLLECTION_IN_MILLION_(USD) son:
#                                        count        mean         std     min  \
# worldwide_collection_in_million_(USD)   27.0  951.648519  592.519375  264.77
#
#                                           25%     50%       75%     max
# worldwide_collection_in_million_(USD)  552.34  773.35  1184.075  2797.5
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el TOMATOMETER son:
#              count      mean       std  min  25%  50%   75%  max
# tomatometer   27.0  8.355556  1.111248  4.7  7.9  8.7  9.15  9.6
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el TOMATO_AUDIENCE_SCORE son:
#                        count     mean       std  min  25%  50%  75%  max
# tomato_audience_score   27.0  8.37037  1.099586  4.5  7.8  8.7  9.1  9.8
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el IMDB son:
#       count      mean       std  min   25%  50%   75%  max
# imdb   27.0  7.407407  0.567671  6.4  6.95  7.4  7.85  8.4
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el METASCORE son:
#            count      mean       std  min  25%  50%   75%  max
# metascore   27.0  6.814815  0.798895  5.2  6.4  6.9  7.25  8.8
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el META_USER_SCORE son:
#                  count      mean       std  min  25%  50%  75%  max
# meta_user_score   27.0  7.281481  1.127638  3.0  6.9  7.5  8.0  8.6

# %% [markdown]
# ##### Exploración CSV north_america

# %%
df_north_america = pd.read_csv("./files/north_america_box_office.csv")
df_north_america
# Out:
#                                   movie_title  USA_and_Canada  Mexico  \
# 0                                    Iron Man          319.03   15.95
# 1                         The Incredible Hulk          134.81   12.65
# 2                                  Iron Man 2          312.43   18.40
# 3                                        Thor          181.03   19.55
# 4          Captain America: The First Avenger          176.65   20.22
# 5                                The Avengers          623.36   61.75
# 6                                  Iron Man 3          409.01   48.57
# 7                        Thor: The Dark World          206.36   23.86
# 8         Captain America: The Winter Soldier          259.77   25.72
# 9                     Guardians of the Galaxy          333.72   19.65
# 10                    Avengers: Age of Ultron          459.01   50.94
# 11                                    Ant-Man          180.20   15.10
# 12                 Captain America: Civil War          408.08   41.42
# 13                             Doctor Strange          232.64   13.59
# 14             Guardians of the Galaxy Vol. 2          389.81   19.01
# 15                     Spider-Man: Homecoming          334.20   27.07
# 16                             Thor: Ragnarok          315.06   21.25
# 17                              Black Panther          700.43   28.32
# 18                     Avengers: Infinity War          678.82   60.06
# 19                       Ant-Man and the Wasp          216.65   14.96
# 20                             Captain Marvel          426.83   33.31
# 21                          Avengers: Endgame          858.37   77.59
# 22                  Spider-Man: Far From Home          390.53   32.30
# 23                                Black Widow          183.65    9.86
# 24  Shang-Chi and the Legend of the Ten Rings          224.54    7.67
# 25                                   Eternals          164.87   15.30
# 26                    Spider-Man: No Way Home          804.62   75.85
#
#     Central America  Caribbean
# 0              1.37       1.37
# 1              0.70       0.70
# 2              6.57       6.57
# 3              5.29       5.29
# 4              3.84       3.84
# 5             11.73      11.73
# 6              8.84       8.84
# 7              7.84       7.84
# 8              6.70       6.70
# 9              9.94       9.94
# 10             8.01       8.01
# 11             2.77       2.77
# 12            11.04      11.04
# 13             4.39       4.39
# 14             3.27       3.27
# 15             2.28       2.28
# 16             4.73       4.73
# 17             7.34       7.34
# 18            18.11      18.11
# 19             3.30       3.30
# 20             6.71       6.71
# 21            14.36      14.36
# 22             5.75       5.75
# 23             2.71       2.71
# 24             2.85       2.85
# 25             2.28       2.28
# 26            36.72      36.72

# %%
df_middle_east_and_africa = pd.read_csv("./files/middle_east_and_africa_box_office.csv")
df_middle_east_and_africa
# Out:
#                                   movie_title  United Arab Emirates  Israel  \
# 0                                    Iron Man                  1.84    0.61
# 1                         The Incredible Hulk                  1.81    0.49
# 2                                  Iron Man 2                  2.25    0.68
# 3                                        Thor                  2.07    0.75
# 4          Captain America: The First Avenger                  1.33    0.72
# 5                                The Avengers                  6.69    2.45
# 6                                  Iron Man 3                  5.73    2.15
# 7                        Thor: The Dark World                  3.45    1.15
# 8         Captain America: The Winter Soldier                  3.93    1.22
# 9                     Guardians of the Galaxy                  2.34    1.90
# 10                    Avengers: Age of Ultron                  3.17    2.02
# 11                                    Ant-Man                  2.89    1.34
# 12                 Captain America: Civil War                  5.96     NaN
# 13                             Doctor Strange                  3.44     NaN
# 14             Guardians of the Galaxy Vol. 2                  2.90     NaN
# 15                     Spider-Man: Homecoming                  5.02    2.60
# 16                             Thor: Ragnarok                  4.59     NaN
# 17                              Black Panther                  6.99     NaN
# 18                     Avengers: Infinity War                 10.07     NaN
# 19                       Ant-Man and the Wasp                  3.23     NaN
# 20                             Captain Marvel                  5.77     NaN
# 21                          Avengers: Endgame                 12.78     NaN
# 22                  Spider-Man: Far From Home                  6.44    3.15
# 23                                Black Widow                  3.23     NaN
# 24  Shang-Chi and the Legend of the Ten Rings                  3.44     NaN
# 25                                   Eternals                  2.54     NaN
# 26                    Spider-Man: No Way Home                 12.10    2.70
#
#     South Africa  Nigeria  Ghana  Kenya  East Africa  Lebanon  Egypt  Kuwait  \
# 0           1.46     0.05    NaN    NaN         0.09     0.10   0.27    0.84
# 1           0.93     0.03    NaN    NaN         0.08     0.10   0.28    0.66
# 2           2.59     0.06   0.01    NaN         0.12     0.17   0.30     NaN
# 3           2.01     0.14   0.03    NaN         0.05     0.28   0.16     NaN
# 4           1.04     0.06   0.02    NaN         0.04     0.17   0.11     NaN
# 5           4.61     0.20   0.02    NaN         0.32     0.53   0.91     NaN
# 6           3.19      NaN    NaN    NaN         0.35     0.58   0.80     NaN
# 7           2.07     0.16    NaN    NaN         0.20     0.52   0.54     NaN
# 8           1.41     0.07    NaN    NaN         0.16     0.31   0.42     NaN
# 9           1.48     0.12    NaN   0.15         0.15     0.18   0.38     NaN
# 10          3.28     0.27    NaN   0.32          NaN     0.54   1.22     NaN
# 11          0.75     0.10   0.36   0.12          NaN     0.34    NaN     NaN
# 12          2.13      NaN    NaN    NaN          NaN      NaN    NaN     NaN
# 13          1.16      NaN    NaN    NaN          NaN      NaN    NaN     NaN
# 14          1.55      NaN    NaN    NaN          NaN      NaN    NaN     NaN
# 15          2.31     0.28   0.05   0.26          NaN     0.63   0.53    1.67
# 16          2.55      NaN    NaN    NaN          NaN      NaN    NaN     NaN
# 17          8.00      NaN    NaN    NaN          NaN      NaN    NaN     NaN
# 18          5.55      NaN    NaN    NaN          NaN      NaN    NaN     NaN
# 19          1.35      NaN    NaN    NaN          NaN      NaN    NaN     NaN
# 20          3.48     0.66    NaN    NaN          NaN      NaN    NaN     NaN
# 21          7.17     1.36    NaN    NaN          NaN      NaN   1.75     NaN
# 22          2.33     0.44   0.06   0.24          NaN     0.73   1.03    2.36
# 23          0.17      NaN    NaN    NaN          NaN      NaN    NaN     NaN
# 24          0.80      NaN    NaN    NaN          NaN      NaN    NaN     NaN
# 25          0.82      NaN    NaN    NaN          NaN      NaN    NaN     NaN
# 26          6.20      NaN    NaN    NaN          NaN      NaN   1.30    1.20
#
#     Turkey  Other_Middle_East_and_African_Countries
# 0     1.66                                     1.37
# 1     1.02                                     0.70
# 2     1.84                                     6.57
# 3     2.09                                     5.29
# 4     1.08                                     3.84
# 5     4.26                                    11.73
# 6     4.51                                     8.84
# 7     3.69                                     7.84
# 8     2.36                                     6.70
# 9     1.92                                     9.94
# 10    5.86                                     8.01
# 11     NaN                                     2.77
# 12    5.05                                    11.04
# 13    3.20                                     4.39
# 14    1.53                                     3.27
# 15    2.66                                     2.28
# 16    2.98                                     4.73
# 17    2.59                                     7.34
# 18    5.70                                    18.11
# 19    1.11                                     3.30
# 20    3.25                                     6.71
# 21    7.92                                    14.36
# 22    2.97                                     5.75
# 23     NaN                                     2.71
# 24    0.66                                     2.85
# 25    0.66                                     2.28
# 26    5.33                                    36.72

# %%
df_europa = pd.read_csv("./files/europe_box_office.csv")
df_europa
# Out:
#                                   movie_title  United Kingdom  Spain  Italy  \
# 0                                    Iron Man           34.28  12.03  10.81
# 1                         The Incredible Hulk           15.16   7.69   6.46
# 2                                  Iron Man 2           30.46   7.60   9.98
# 3                                        Thor           22.52  12.44  10.90
# 4          Captain America: The First Avenger           14.75   7.71   8.60
# 5                                The Avengers           80.56  20.22  22.01
# 6                                  Iron Man 3           57.07  13.05  20.91
# 7                        Thor: The Dark World           26.22   8.86  11.18
# 8         Captain America: The Winter Soldier           32.23   7.76   9.73
# 9                     Guardians of the Galaxy           37.21  10.15   7.01
# 10                    Avengers: Age of Ultron           62.97  13.64  18.12
# 11                                    Ant-Man           25.19   4.15   5.29
# 12                 Captain America: Civil War           53.78  11.35  12.96
# 13                             Doctor Strange           28.55   6.98   8.19
# 14             Guardians of the Galaxy Vol. 2           53.06  10.31   7.90
# 15                     Spider-Man: Homecoming           39.58  11.95  10.16
# 16                             Thor: Ragnarok           40.96  10.62   9.87
# 17                              Black Panther           70.75   9.72   8.95
# 18                     Avengers: Infinity War           96.64  24.81  22.84
# 19                       Ant-Man and the Wasp           22.94   6.87   5.82
# 20                             Captain Marvel           51.79  14.70  11.46
# 21                          Avengers: Endgame          115.00  32.67  34.15
# 22                  Spider-Man: Far From Home           49.57  15.12  13.50
# 23                                Black Widow           25.78   7.33   5.78
# 24  Shang-Chi and the Legend of the Ten Rings           29.32   6.97   4.56
# 25                                   Eternals           19.96   8.59   9.77
# 26                    Spider-Man: No Way Home          126.89  30.92  27.23
#
#     Germany  Denmark  Hungary  Finland  Netherlands  Iceland  ...  Poland  \
# 0      8.56     2.22     0.68     0.67         2.10     0.28  ...    1.00
# 1      2.46     1.10     0.31     0.22         1.34     0.15  ...    0.48
# 2      9.25     2.29     0.70     0.80         2.14     0.20  ...    1.14
# 3     16.01     1.53     0.74     0.42         1.95     0.26  ...    1.61
# 4      4.87     1.05     0.51     0.31         1.63     0.20  ...    0.45
# 5     30.83     5.08     1.76     1.48         6.61     0.50  ...    3.17
# 6     24.37     4.43     2.02     1.89         5.72     0.38  ...    4.25
# 7     20.36     2.13     1.10     1.13         3.21     0.31  ...    3.16
# 8     12.48     1.89     1.05     0.83         2.62     0.23  ...    1.38
# 9     24.60     2.65     1.63     1.38         3.67     0.42  ...    2.52
# 10    31.19     4.58     1.98     1.34         5.47     0.37  ...    3.97
# 11     5.92     0.92      NaN     0.60         1.85     0.18  ...    1.30
# 12    21.77     3.08      NaN     1.43         4.39     0.34  ...    2.69
# 13    17.40     2.29     1.21     1.29         3.61     0.29  ...    2.46
# 14    30.17     3.29     1.71     1.53         4.46     0.47  ...    3.25
# 15    11.66     2.47     1.06     1.16         4.04     0.33  ...    2.69
# 16    19.04     2.92     2.20     1.46         4.59     0.48  ...    4.05
# 17    23.39     4.80     1.57     2.20         9.98     0.50  ...    3.60
# 18    45.40     6.85     3.17     3.38        10.43     0.69  ...    7.37
# 19     9.42     1.07     0.99     0.77         2.66     0.23  ...    2.43
# 20    24.31     3.55     2.10     2.08         6.63     0.39  ...    4.51
# 21    63.29    10.25     4.50     4.94        15.07     0.75  ...   10.56
# 22    19.42     3.88     1.72     1.90         7.42     0.36  ...    4.49
# 23     8.47     0.18     1.38     1.09         4.55     0.24  ...    2.67
# 24     9.41     0.80     0.89     0.97         4.09     0.22  ...    2.04
# 25     9.40     0.67     0.75     0.68         2.39     0.15  ...    2.16
# 26    50.23      NaN     3.14      NaN        13.00     0.76  ...     NaN
#
#     Serbia and Montenegro  Estonia  Slovenia  Sweden  Belgium  Norway  Greece  \
# 0                    0.03     0.08      0.09    2.06     1.97    1.86    1.80
# 1                    0.05     0.03      0.06    1.08     1.08    1.53    0.83
# 2                    0.04     0.08      0.12    1.97     1.89    2.46    1.57
# 3                    0.07     0.13      0.12    2.29     1.26    2.03    1.85
# 4                    0.03     0.10      0.07    1.50     1.03    1.41    0.77
# 5                    0.17      NaN      0.16    7.60     4.06    5.64    2.60
# 6                    0.12      NaN      0.18    5.50     3.51    5.33    2.05
# 7                    0.15      NaN      0.15    3.94     2.23    2.55    1.27
# 8                    0.07      NaN      0.08    2.12     1.68    1.84    1.05
# 9                    0.21      NaN      0.14    5.27     2.84    3.08    0.70
# 10                   0.19     0.26      0.12    5.24     3.31    4.77    1.78
# 11                   0.07     0.11      0.04    2.14     1.24    1.36    0.36
# 12                    NaN      NaN      0.10    3.61     2.49    2.52     NaN
# 13                    NaN      NaN      0.09    3.14     1.89    1.54    1.18
# 14                    NaN      NaN      0.12    4.50     2.55    2.47    0.63
# 15                   0.18     0.20      0.10    3.68     2.28    2.83    1.11
# 16                    NaN      NaN      0.19    4.54     2.57    2.75    1.30
# 17                   0.31      NaN      0.21    7.44     3.85    4.25    1.24
# 18                   0.28      NaN      0.33    8.07     5.65    5.69    2.82
# 19                    NaN      NaN      0.07    1.97     1.33    1.43    0.51
# 20                   0.29      NaN      0.19    4.74     3.59    2.99    1.56
# 21                   0.80      NaN      0.61   11.76     8.68    8.16    4.18
# 22                   0.32     0.40      0.24    4.46     3.51    3.65    1.68
# 23                    NaN      NaN      0.08    2.37     1.90    1.24     NaN
# 24                   0.14      NaN      0.06    2.37     1.87    1.49     NaN
# 25                   0.18      NaN      0.07    2.30     1.84    0.93     NaN
# 26                   1.08      NaN      0.59     NaN      NaN    2.60     NaN
#
#     France  Other_European_Countries
# 0    19.20                      1.37
# 1     9.73                      0.70
# 2    19.79                      6.57
# 3    18.37                      5.29
# 4    10.28                      3.84
# 5    37.77                     11.73
# 6    38.96                      8.84
# 7    22.29                      7.84
# 8    16.89                      6.70
# 9    19.89                      9.94
# 10   34.27                      8.01
# 11   13.56                      2.77
# 12   23.22                     11.04
# 13   15.69                      4.39
# 14   24.81                      3.27
# 15   18.79                      2.28
# 16   21.26                      4.73
# 17   33.11                      7.34
# 18   47.69                     18.11
# 19   14.72                      3.30
# 20   27.09                      6.71
# 21   62.19                     14.36
# 22   26.19                      5.75
# 23   15.13                      2.71
# 24   12.97                      2.85
# 25   16.24                      2.28
# 26   57.21                     36.72
#
# [27 rows x 31 columns]

# %%
exploracion_dataframe(df_europa)
# Out:
# Tenemos 0 duplicados en el conjunto de datos.
#
#  -----
#
# Los nulos que tenemos en el conjunto de datos son:
#                          %_nulos
# Denmark                 3.703704
# Hungary                 7.407407
# Finland                 3.703704
# Switzerland            29.629630
# Romania                22.222222
# Lithuania              18.518519
# Latvia                 66.666667
# Croatia                14.814815
# Austria                 3.703704
# Poland                  3.703704
# Serbia and Montenegro  22.222222
# Estonia                66.666667
# Sweden                  3.703704
# Belgium                 3.703704
# Greece                 18.518519
#  -----
#
# Los tipos de las columnas son:
#                          tipo_dato
# movie_title                 object
# United Kingdom             float64
# Spain                      float64
# Italy                      float64
# Germany                    float64
# Denmark                    float64
# Hungary                    float64
# Finland                    float64
# Netherlands                float64
# Iceland                    float64
# Czech Republic             float64
# Switzerland                float64
# Slovakia                   float64
# Ukraine                    float64
# Portugal                   float64
# Romania                    float64
# Lithuania                  float64
# Bulgaria                   float64
# Latvia                     float64
# Croatia                    float64
# Austria                    float64
# Poland                     float64
# Serbia and Montenegro      float64
# Estonia                    float64
# Slovenia                   float64
# Sweden                     float64
# Belgium                    float64
# Norway                     float64
# Greece                     float64
# France                     float64
# Other_European_Countries   float64
#  -----
#
# Los valores que tenemos para las COLUMNAS CATEGÓRICAS son:
# La columna MOVIE_TITLE tiene las siguientes valores únicos:
#                                            count
# movie_title
# Iron Man                                       1
# Guardians of the Galaxy Vol. 2                 1
# Eternals                                       1
# Shang-Chi and the Legend of the Ten Rings      1
# Black Widow                                    1
#  -----
#
# Los principales estadísticos de las COLUMNAS CATEGÓRICAS para el MOVIE_TITLE son:
#             count unique       top freq
# movie_title    27     27  Iron Man    1
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el UNITED KINGDOM son:
#                 count       mean        std    min   25%    50%     75%  \
# United Kingdom   27.0  46.784815  29.380227  14.75  26.0  37.21  55.425
#
#                    max
# United Kingdom  126.89
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el SPAIN son:
#        count       mean       std   min  25%    50%     75%    max
# Spain   27.0  12.378148  7.081643  4.15  7.7  10.31  13.345  32.67
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el ITALY son:
#        count       mean       std   min    25%   50%    75%    max
# Italy   27.0  12.375556  7.251643  4.56  8.045  9.98  13.23  34.15
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el GERMANY son:
#          count       mean        std   min    25%    50%     75%    max
# Germany   27.0  20.506667  14.473195  2.46  9.405  19.04  24.485  63.29
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el DENMARK son:
#          count      mean       std   min     25%   50%     75%    max
# Denmark   26.0  2.921923  2.194201  0.18  1.2075  2.38  3.7975  10.25
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el HUNGARY son:
#          count    mean       std   min   25%   50%   75%  max
# Hungary   25.0  1.5548  0.958984  0.31  0.89  1.38  1.98  4.5
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el FINLAND son:
#          count      mean       std   min     25%    50%     75%   max
# Finland   26.0  1.382692  0.996115  0.22  0.7775  1.225  1.5175  4.94
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el NETHERLANDS son:
#              count      mean       std   min    25%   50%    75%    max
# Netherlands   27.0  5.022963  3.506746  1.34  2.505  4.09  6.165  15.07
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el ICELAND son:
#          count      mean       std   min   25%   50%    75%   max
# Iceland   27.0  0.358519  0.170558  0.15  0.23  0.33  0.445  0.76
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el CZECH REPUBLIC son:
#                 count      mean       std   min   25%  50%    75%   max
# Czech Republic   27.0  1.834815  1.494306  0.15  1.02  1.4  2.055  6.61
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el SWITZERLAND son:
#              count      mean       std   min    25%   50%    75%   max
# Switzerland   19.0  2.790526  2.091295  0.32  1.385  2.23  3.655  8.79
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el SLOVAKIA son:
#           count      mean       std   min    25%   50%    75%   max
# Slovakia   27.0  0.560741  0.409041  0.09  0.345  0.47  0.645  1.99
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el UKRAINE son:
#          count      mean       std   min   25%   50%    75%   max
# Ukraine   27.0  2.154074  1.735067  0.01  1.24  1.63  2.485  8.44
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el PORTUGAL son:
#           count      mean       std   min   25%   50%   75%  max
# Portugal   27.0  1.641111  0.899967  0.71  1.09  1.34  1.92  4.3
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el ROMANIA son:
#          count      mean       std   min   25%   50%   75%   max
# Romania   21.0  1.263333  0.896411  0.15  0.68  1.14  1.68  3.38
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el LITHUANIA son:
#            count   mean       std   min  25%   50%     75%   max
# Lithuania   22.0  0.215  0.198392  0.05  0.1  0.17  0.2175  0.87
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el BULGARIA son:
#           count      mean       std   min    25%   50%    75%   max
# Bulgaria   27.0  0.445926  0.297014  0.03  0.175  0.46  0.645  1.12
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el LATVIA son:
#         count      mean       std   min   25%  50%   75%   max
# Latvia    9.0  0.124444  0.075185  0.05  0.06  0.1  0.14  0.28
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el CROATIA son:
#          count      mean       std   min    25%   50%    75%   max
# Croatia   23.0  0.402174  0.307748  0.09  0.195  0.31  0.455  1.27
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el AUSTRIA son:
#          count      mean       std   min     25%   50%   75%   max
# Austria   26.0  2.527692  1.694429  0.41  1.3925  2.34  3.11  8.38
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el POLAND son:
#         count      mean       std   min     25%   50%     75%    max
# Poland   26.0  3.053846  2.147486  0.45  1.7175  2.68  3.8775  10.56
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el SERBIA AND MONTENEGRO son:
#                        count      mean       std   min   25%   50%   75%   max
# Serbia and Montenegro   21.0  0.227619  0.257913  0.03  0.07  0.17  0.28  1.08
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el ESTONIA son:
#          count      mean       std   min   25%   50%  75%  max
# Estonia    9.0  0.154444  0.114903  0.03  0.08  0.11  0.2  0.4
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el SLOVENIA son:
#           count      mean       std   min   25%   50%    75%   max
# Slovenia   27.0  0.162222  0.141784  0.04  0.08  0.12  0.185  0.61
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el SWEDEN son:
#         count      mean       std   min     25%    50%    75%    max
# Sweden   26.0  4.063846  2.482521  1.08  2.1775  3.645  5.115  11.76
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el BELGIUM son:
#          count      mean       std   min     25%    50%   75%   max
# Belgium   26.0  2.696154  1.637813  1.03  1.8475  2.255  3.46  8.68
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el NORWAY son:
#         count      mean       std   min    25%   50%    75%   max
# Norway   27.0  2.903704  1.727769  0.93  1.535  2.52  3.365  8.16
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el GREECE son:
#         count      mean       std   min    25%    50%    75%   max
# Greece   22.0  1.492727  0.874066  0.36  0.885  1.285  1.795  4.18
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el FRANCE son:
#         count       mean       std   min     25%    50%   75%    max
# France   27.0  25.085556  13.59064  9.73  15.965  19.89  30.1  62.19
#  -----
#
# Los principales estadísticos de las COLUMNAS NUMÉRICAS para el OTHER_EUROPEAN_COUNTRIES son:
#                           count      mean      std  min   25%   50%    75%  \
# Other_European_Countries   27.0  7.386667  7.16098  0.7  3.06  5.75  8.425
#
#                             max
# Other_European_Countries  36.72
